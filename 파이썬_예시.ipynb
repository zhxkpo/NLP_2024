# %% [markdown]
# <a href="https://colab.research.google.com/github/zhxkpo/NLP_2024/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EC%98%88%EC%8B%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #공공데이터포탈
# !git clone https://github.com/zhxkpo/NLP_2024 #https://www.data.go.kr/tcs/dss/selectDataSetList.do?keyword=%EA%B5%90%ED%86%B5%EC%82%AC%EA%B3%A0
# Out:
# fatal: destination path 'NLP_2024' already exists and is not an empty directory.

# %%
traffic_df = pd.read_csv("/content/NLP_2024/한국도로교통공단_사고유형별 교통사고 통계_20231231.csv", encoding="euc-kr")

# %%
traffic_df
# Out:
#    사고유형대분류     사고유형중분류        사고유형   사고건수  사망자수   중상자수   경상자수  부상신고자수
# 0     차대사람         횡단중         횡단중  13081   419   5868   6999     664
# 1     차대사람       차도통행중       차도통행중   4507   135   1704   2491     355
# 2     차대사람  길가장자리구역통행중  길가장자리구역통행중   1985    28    544   1303     190
# 3     차대사람       보도통행중       보도통행중   2632    24    849   1735     206
# 4     차대사람          기타          기타  14791   253   4778   9111    1466
# 5      차대차        정면충돌        정면충돌   7899   162   3498   8781     612
# 6      차대차        측면충돌        측면충돌  65621   317  15386  77040    5983
# 7      차대차       후진중충돌       후진중충돌   4017     3    301   4724     254
# 8      차대차          추돌          추돌  31939   325   7197  46557    3300
# 9      차대차          기타          기타  43459   234   9735  48179    4740
# 10    차량단독          전도          전도    895    83    329    395     185
# 11    차량단독          전복          전복    130    18     48     71      20
# ...

# %%
traffic_df2 = traffic_df.set_index('사고유형대분류')
traffic_df2
# Out:
#             사고유형중분류        사고유형   사고건수  사망자수   중상자수   경상자수  부상신고자수
# 사고유형대분류
# 차대사람            횡단중         횡단중  13081   419   5868   6999     664
# 차대사람          차도통행중       차도통행중   4507   135   1704   2491     355
# 차대사람     길가장자리구역통행중  길가장자리구역통행중   1985    28    544   1303     190
# 차대사람          보도통행중       보도통행중   2632    24    849   1735     206
# 차대사람             기타          기타  14791   253   4778   9111    1466
# 차대차            정면충돌        정면충돌   7899   162   3498   8781     612
# 차대차            측면충돌        측면충돌  65621   317  15386  77040    5983
# 차대차           후진중충돌       후진중충돌   4017     3    301   4724     254
# 차대차              추돌          추돌  31939   325   7197  46557    3300
# 차대차              기타          기타  43459   234   9735  48179    4740
# 차량단독             전도          전도    895    83    329    395     185
# 차량단독             전복          전복    130    18     48     71      20
# 차량단독          공작물충돌       공작물충돌   2809   307   1163   1619     587
# ...

# %%
a=traffic_df['사고건수'].sum()
a
# Out:
# 198296

# %%
import matplotlib.pyplot as plt

# %%
transposed_df2 = traffic_df.transpose()
transposed_df2
# Out:
#             0      1           2      3      4     5      6      7      8   \
# 사고유형대분류   차대사람   차대사람        차대사람   차대사람   차대사람   차대차    차대차    차대차    차대차
# 사고유형중분류    횡단중  차도통행중  길가장자리구역통행중  보도통행중     기타  정면충돌   측면충돌  후진중충돌     추돌
# 사고유형       횡단중  차도통행중  길가장자리구역통행중  보도통행중     기타  정면충돌   측면충돌  후진중충돌     추돌
# 사고건수     13081   4507        1985   2632  14791  7899  65621   4017  31939
# 사망자수       419    135          28     24    253   162    317      3    325
# 중상자수      5868   1704         544    849   4778  3498  15386    301   7197
# 경상자수      6999   2491        1303   1735   9111  8781  77040   4724  46557
# 부상신고자수     664    355         190    206   1466   612   5983    254   3300
#
#             9     10    11     12         13       14       15    16     17
# 사고유형대분류    차대차  차량단독  차량단독   차량단독       차량단독     차량단독     차량단독  차량단독  철길건널목
# 사고유형중분류     기타    전도    전복  공작물충돌  주/정차차량 충돌     도로이탈     도로이탈    기타  철길건널목
# ...

# %%
transposed_df2['total']=traffic_df.select_dtypes(include='number').sum()
transposed_df2
# Out:
#              0      1           2      3      4     5      6      7      8  \
# 사고유형대분류   차대사람   차대사람        차대사람   차대사람   차대사람   차대차    차대차    차대차    차대차
# 사고유형중분류    횡단중  차도통행중  길가장자리구역통행중  보도통행중     기타  정면충돌   측면충돌  후진중충돌     추돌
# 사고유형       횡단중  차도통행중  길가장자리구역통행중  보도통행중     기타  정면충돌   측면충돌  후진중충돌     추돌
# 사고건수     13081   4507        1985   2632  14791  7899  65621   4017  31939
# 사망자수       419    135          28     24    253   162    317      3    325
# 중상자수      5868   1704         544    849   4778  3498  15386    301   7197
# 경상자수      6999   2491        1303   1735   9111  8781  77040   4724  46557
# 부상신고자수     664    355         190    206   1466   612   5983    254   3300
#
#              9    10    11     12         13       14       15    16     17  \
# 사고유형대분류    차대차  차량단독  차량단독   차량단독       차량단독     차량단독     차량단독  차량단독  철길건널목
# 사고유형중분류     기타    전도    전복  공작물충돌  주/정차차량 충돌     도로이탈     도로이탈    기타  철길건널목
# ...

# %%
transposed_df2['total'].fillna(0,inplace=True)
transposed_df2
# Out:
# <ipython-input-68-f3a5871360a6>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   transposed_df2['total'].fillna(0,inplace=True)
#              0      1           2      3      4     5      6      7      8  \
# 사고유형대분류   차대사람   차대사람        차대사람   차대사람   차대사람   차대차    차대차    차대차    차대차
# 사고유형중분류    횡단중  차도통행중  길가장자리구역통행중  보도통행중     기타  정면충돌   측면충돌  후진중충돌     추돌
# 사고유형       횡단중  차도통행중  길가장자리구역통행중  보도통행중     기타  정면충돌   측면충돌  후진중충돌     추돌
# 사고건수     13081   4507        1985   2632  14791  7899  65621   4017  31939
# ...

# %%
transposed_df3=transposed_df2['total'].astype('int')
transposed_df3
# Out:
# 사고유형대분류         0
# 사고유형중분류         0
# 사고유형            0
# 사고건수       198296
# 사망자수         2551
# 중상자수        52989
# 경상자수       211569
# 부상신고자수      19241
# Name: total, dtype: int64
